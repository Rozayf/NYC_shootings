# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Internet_Master_Plan__Adoption_and_Infrastructure_Data_by_Neighborhood.csv')

# %%
data
# Out:
#     Neighborhood Tabulation Area Code (NTA Code)  \
# 0                                           BK09
# 1                                           BK17
# 2                                           BK19
# 3                                           BK21
# 4                                           BK23
# ..                                           ...
# 190                                         SI37
# 191                                         SI45
# 192                                         SI48
# 193                                         SI54
# 194                                         SI99
#
#        Neighborhood Tabulation Area Name (NTA NAME)   Borough Name  \
# 0                      Brooklyn Heights-Cobble Hill       Brooklyn
# 1    Sheepshead Bay-Gerritsen Beach-Manhattan Beach       Brooklyn
# 2                                    Brighton Beach       Brooklyn
# 3                              Seagate-Coney Island       Brooklyn
# ...

# %%
data['Borough Name'].value_counts()
# Out:
# Queens           58
# Brooklyn         51
# Bronx            38
# Manhattan        29
# Staten Island    19
# Name: Borough Name, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#     Neighborhood Tabulation Area Code (NTA Code)  \
# 0                                           BK09
# 1                                           BK17
# 2                                           BK19
# 3                                           BK21
# 4                                           BK23
# ..                                           ...
# 190                                         SI37
# 191                                         SI45
# 192                                         SI48
# 193                                         SI54
# 194                                         SI99
#
#        Neighborhood Tabulation Area Name (NTA NAME)   Borough Name  \
# 0                      Brooklyn Heights-Cobble Hill       Brooklyn
# 1    Sheepshead Bay-Gerritsen Beach-Manhattan Beach       Brooklyn
# 2                                    Brighton Beach       Brooklyn
# 3                              Seagate-Coney Island       Brooklyn
# ...

# %%
 Households_Receiving_Benefits_Avg_by_area = data.groupby(['Borough Name']).agg({'Households Receiving Benefits':np.mean})

# %%
Households_Receiving_Benefits_Avg_by_area
# Out:
#                Households Receiving Benefits
# Borough Name
# Bronx                             931.289474
# Brooklyn                          837.921569
# Manhattan                         699.517241
# Queens                            466.034483
# Staten Island                     318.111111

# %%
Low_income_Housing_Avg_by_Area = data.groupby(['Borough Name']).agg({'Low-Income Housing (NYCHA)':np.mean})

# %%
Low_income_Housing_Avg_by_Area
# Out:
#                Low-Income Housing (NYCHA)
# Borough Name
# Bronx                         2493.921053
# Brooklyn                      2670.078431
# Manhattan                     4036.241379
# Queens                         566.206897
# Staten Island                  523.842105
